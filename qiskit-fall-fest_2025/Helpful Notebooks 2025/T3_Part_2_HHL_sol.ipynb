# %% [markdown]
# The HHL Algorithm
#
# The [HHL algorithm](https://en.wikipedia.org/wiki/Quantum_algorithm_for_linear_systems_of_equations) underlies many quantum machine learning protocols, but it is a highly nontrivial algorithm with lots of conditions. In this notebook, we implement the algorithm to gain a better understanding of how it works and when it works efficiently. The notebook is derived from the [computational appendix](https://gitlab.com/apozas/bayesian-dl-quantum) of the paper [Bayesian Deep Learning on a Quantum Computer](https://arxiv.org/abs/1806.11463). We restrict our attention to inverting a $2\times 2$ matrix, following Pan *et al*.'s implementation [[1](#1)] of the algorithm.

# %%
# !pip install qiskit
# !pip install qiskit-aer
# !pip install numpy
# Out:
# Requirement already satisfied: qiskit in /Users/Stef/anaconda3/envs/MLenv/lib/python3.11/site-packages (2.1.1)
# Requirement already satisfied: rustworkx>=0.15.0 in /Users/Stef/anaconda3/envs/MLenv/lib/python3.11/site-packages (from qiskit) (0.16.0)
# Requirement already satisfied: numpy<3,>=1.17 in /Users/Stef/anaconda3/envs/MLenv/lib/python3.11/site-packages (from qiskit) (1.26.4)
# Requirement already satisfied: scipy>=1.5 in /Users/Stef/anaconda3/envs/MLenv/lib/python3.11/site-packages (from qiskit) (1.12.0)
# Requirement already satisfied: dill>=0.3 in /Users/Stef/anaconda3/envs/MLenv/lib/python3.11/site-packages (from qiskit) (0.3.7)
# Requirement already satisfied: stevedore>=3.0.0 in /Users/Stef/anaconda3/envs/MLenv/lib/python3.11/site-packages (from qiskit) (5.4.1)
# Requirement already satisfied: typing-extensions in /Users/Stef/anaconda3/envs/MLenv/lib/python3.11/site-packages (from qiskit) (4.14.1)
# Requirement already satisfied: pbr>=2.0.0 in /Users/Stef/anaconda3/envs/MLenv/lib/python3.11/site-packages (from stevedore>=3.0.0->qiskit) (6.1.1)
# Requirement already satisfied: setuptools in /Users/Stef/anaconda3/envs/MLenv/lib/python3.11/site-packages (from pbr>=2.0.0->stevedore>=3.0.0->qiskit) (69.2.0)
# Requirement already satisfied: qiskit-aer in /Users/Stef/anaconda3/envs/MLenv/lib/python3.11/site-packages (0.17.1)
# Requirement already satisfied: qiskit>=1.1.0 in /Users/Stef/anaconda3/envs/MLenv/lib/python3.11/site-packages (from qiskit-aer) (2.1.1)
# Requirement already satisfied: numpy>=1.16.3 in /Users/Stef/anaconda3/envs/MLenv/lib/python3.11/site-packages (from qiskit-aer) (1.26.4)
# Requirement already satisfied: scipy>=1.0 in /Users/Stef/anaconda3/envs/MLenv/lib/python3.11/site-packages (from qiskit-aer) (1.12.0)
# Requirement already satisfied: psutil>=5 in /Users/Stef/anaconda3/envs/MLenv/lib/python3.11/site-packages (from qiskit-aer) (5.9.8)
# Requirement already satisfied: python-dateutil>=2.8.0 in /Users/Stef/anaconda3/envs/MLenv/lib/python3.11/site-packages (from qiskit-aer) (2.9.0)
# Requirement already satisfied: six>=1.5 in /Users/Stef/anaconda3/envs/MLenv/lib/python3.11/site-packages (from python-dateutil>=2.8.0->qiskit-aer) (1.16.0)
# Requirement already satisfied: rustworkx>=0.15.0 in /Users/Stef/anaconda3/envs/MLenv/lib/python3.11/site-packages (from qiskit>=1.1.0->qiskit-aer) (0.16.0)
# Requirement already satisfied: dill>=0.3 in /Users/Stef/anaconda3/envs/MLenv/lib/python3.11/site-packages (from qiskit>=1.1.0->qiskit-aer) (0.3.7)
# Requirement already satisfied: stevedore>=3.0.0 in /Users/Stef/anaconda3/envs/MLenv/lib/python3.11/site-packages (from qiskit>=1.1.0->qiskit-aer) (5.4.1)
# Requirement already satisfied: typing-extensions in /Users/Stef/anaconda3/envs/MLenv/lib/python3.11/site-packages (from qiskit>=1.1.0->qiskit-aer) (4.14.1)
# Requirement already satisfied: pbr>=2.0.0 in /Users/Stef/anaconda3/envs/MLenv/lib/python3.11/site-packages (from stevedore>=3.0.0->qiskit>=1.1.0->qiskit-aer) (6.1.1)
# Requirement already satisfied: setuptools in /Users/Stef/anaconda3/envs/MLenv/lib/python3.11/site-packages (from pbr>=2.0.0->stevedore>=3.0.0->qiskit>=1.1.0->qiskit-aer) (69.2.0)
# Requirement already satisfied: numpy in /Users/Stef/anaconda3/envs/MLenv/lib/python3.11/site-packages (1.26.4)

# %%
import numpy as np
from qiskit import QuantumCircuit, ClassicalRegister, QuantumRegister
import qiskit
#from qiskit import transpile, assemble
from qiskit_aer import Aer, AerSimulator
from qiskit.visualization import plot_histogram
π = np.pi
# %matplotlib inline

# %% [markdown]
# # Setting up the problem
#
# We will solve the equation $Ax=b$ with $A = \frac{1}{2}\begin{bmatrix}3 & 1 \\1 & 3 \\ \end{bmatrix}$ and $b =\begin{bmatrix} 1 \\ 0 \\ \end{bmatrix}$. We will encode the $A$ matrix as a Hamiltonian and $b$ in a register. With ancillas, we will need a total of five qubits and one classical register for post-selection. We add an extra qubit and extra classical register to create a swap test to compare our result to the ideal state.

# %%
q = QuantumRegister(6)
c = ClassicalRegister(2)
hhl = QuantumCircuit(q, c)
print(hhl.draw())
# Out:
#
# q0_0:
#
# q0_1:
#
# q0_2:
#
# q0_3:
#
# q0_4:
#
# q0_5:
#
# c0: 2/

# %% [markdown]
# The vector $b$ can be encoded as $\left|b\right\rangle = \sum_{i=0}^N b_i\left|i\right\rangle = \left|0\right\rangle$, so no explicit state preparation circuit is needed for this case (this will not be true in general).
#
# # Quantum phase estimation
#
# The next step is to encode the eigenvalues of the matrix $A$ in an additional register. This is done via quantum phase estimation of the evolution described by the Hamiltonian $A$ during some time $t_0$, $\exp(\imath A t_0)$. The protocol has three steps.
#
# First we prepare the ancilla state $\left|\psi_0\right\rangle=\sum_{\tau=0}^{T-1}\left|\tau\right\rangle$. Why this state? It will control the time evolution: it is like a clock, turning on evolution for a certain amount of time. The original HHL algorithm suggests a weighted superposition of all states $\tau$ that minimizes errors in following steps in the algorithm. However, for our implementation, a uniform superposition already gives good results.
#
# Our goal is to create a superposition of $A$ as a Hamiltonian applied for different durations. Since the eigenvalues are always situated on the complex unit circle, these differently evolved components in the superposition help reveal the eigenstructure. So we apply the conditional Hamiltonian evolution $\sum_{\tau=0}^{T-1}\left|\tau\right\rangle\left\langle\tau\right|\otimes e^{\imath A\tau t_0/T}$ on $\left|\psi_0\right\rangle\otimes\left|b\right\rangle$. This operation evolves the state $\left|b\right\rangle$ according to the Hamiltonian $A$ for the time $\tau$ determined by the state $\left|\psi_0\right\rangle$. Given that in $\left|\psi_0\right\rangle$ we have a superposition of all possible time steps between $0$ and $T$, we will end up with a superposition of all possible evolutions, and a suitable choice of number of timesteps $T$ and total evolution time $t_0$ allow to encode binary representations of the eigenvalues.
#
# As a final step, we apply an inverse Fourier transformation that writes the phases (that, recall, encode the eigenvalues of $A$) into new registers.
#
# The total circuit for phase estimation is the following:
#
# ![Quantum phase estimation in the quantum matrix inversion algorithm](figures/qpe_for_hhl.svg)
#
#
# In our $2\times 2$ case, the circuit is massively simplified. Given that the matrix $A$ has eigenvalues that are powers of $2$, we can choose $T=4$, $t_0=2\pi$ to obtain exact results with just two controlled evolutions.

# %%
# Superposition
hhl.h(q[1])
hhl.h(q[2])
# Controlled-U0
hhl.cu(theta=-π / 2, phi=-π / 2, lam=π / 2, gamma=0, control_qubit=q[2],target_qubit=q[3])
hhl.cp(3 * π / 4, q[2], q[3])
hhl.cx(q[2], q[3])
hhl.cp(3 * π / 4, q[2], q[3])
hhl.cx(q[2], q[3])
# Controlled-U1
hhl.cx(q[1], q[3]);

# %% [markdown]
# We apply quantum inverse Fourier transformation to write the phase to a register:

# %%
hhl.swap(q[1], q[2])
hhl.h(q[2])
hhl.cp(-π / 2, q[1], q[2])
hhl.h(q[1]);

# %% [markdown]
# The state of the system after this decomposition is approximately $\sum _{j{\mathop {=}}1}^{N}\beta _{j}\left|u_{j}\right\rangle \left|\lambda_{j}\right\rangle$, where $\left|b\right\rangle=\sum _{j{\mathop {=}}1}^{N}\beta _{j}\left|u_{j}\right\rangle$ is the encoding of the vector $b$ in the eigenbasis of $A$. Now, there is an often overlooked step that performs bit operations on $\left|\lambda_{j}\right\rangle$ to actually invert it.
#
# In our case, the inversion of the eigenvalues is easy. The eigenvalues of $A$ are $\lambda_1=2=10_2$ and $\lambda_2=1=01_2$, and their reciprocals are $\lambda_1^{-1}=1/2$ and $\lambda_2^{-1}=1$. Noting that $2\lambda_1^{-1}=01_2$ and $2\lambda_2^{-1}=10_2$, a swap gate is enough to obtain the state $\sum _{j{\mathop {=}}1}^{N}\beta _{j}\left|u_{j}\right\rangle \left|2\lambda _{j}^{-1}\right\rangle$, that encodes the reciprocals of the eigenvalues.

# %%
hhl.swap(q[1], q[2]);
print(hhl.draw())
# Out:
#                                                                             »
# q0_0: ──────────────────────────────────────────────────────────────────────»
#       ┌───┐                                                                 »
# q0_1: ┤ H ├──────────────────────────────────────────────────────■───X──────»
#       ├───┤                                                      │   │ ┌───┐»
# q0_2: ┤ H ├──────────■────────────■──────────■───■──────────■────┼───X─┤ H ├»
#       └───┘┌─────────┴──────────┐ │P(3π/4) ┌─┴─┐ │P(3π/4) ┌─┴─┐┌─┴─┐   └───┘»
# q0_3: ─────┤ U(-π/2,-π/2,π/2,0) ├─■────────┤ X ├─■────────┤ X ├┤ X ├────────»
#            └────────────────────┘          └───┘          └───┘└───┘        »
# q0_4: ──────────────────────────────────────────────────────────────────────»
#                                                                             »
# q0_5: ──────────────────────────────────────────────────────────────────────»
#                                                                             »
# c0: 2/══════════════════════════════════════════════════════════════════════»
#                                                                             »
# «
# «q0_0: ──────────────────
# «                ┌───┐
# «q0_1: ─■────────┤ H ├─X─
# «       │P(-π/2) └───┘ │
# «q0_2: ─■──────────────X─
# «
# «q0_3: ──────────────────
# «
# «q0_4: ──────────────────
# «
# «q0_5: ──────────────────
# «
# «c0: 2/══════════════════
# «

# %% [markdown]
# # Conditional rotation of ancilla
#
# Next, we perform a conditional rotation to encode the information of the reciprocals of the eigenvalues in the amplitudes of a state, on which we will later post-select. The state we would like to get is $\sum _{j{\mathop {=}}1}^{N}\beta _{j}\left|u_{j}\right\rangle\left|2\lambda _{j}^{-1}\right\rangle \left(\sqrt{1-\frac{C^2}{\lambda_j^2}}\left|0\right\rangle+\frac{C}{\lambda_j}\left|1\right\rangle \right)$. This is achieved by controlled rotations in the same spirit of the conditional Hamiltonian evolution.

# %%
hhl.cu(π/8, 0, 0, 0, q[1], q[0])  # Controlled-RY0
#pi/8
hhl.cu(π/16, 0, 0, 0, q[2], q[0]);  # Controlled-RY1
#pi/16

# %% [markdown]
# # Uncomputing the eigenvalue register
#
# A necessary step when performing quantum computations is to uncompute all operations except those that store the information that we want to obtain from the algorithm in the final registers. We need to do this in case the registers are entangled, which would affect the results.
#
# In our case, we must uncompute the phase estimation protocol. After the uncomputation, the state should be $\sum_{j=1}^N\beta_j\left|u_j\right\rangle\left|0\right\rangle\left(\sqrt{1-\frac{C^2}{\lambda_j^2}}\left|0\right\rangle+\frac{C}{\lambda_j}\left|1\right\rangle \right)$, so we can safely forget about the eigenvalue register.

# %%
hhl.swap(q[1], q[2])
hhl.h(q[1])
hhl.cp(π / 2, q[1], q[2])  # Inverse(Dagger(Controlled-S))
hhl.h(q[2])
hhl.swap(q[2], q[1])
# Inverse(Controlled-U1)
hhl.cx(q[1], q[3])
# Inverse(Controlled-U0)
hhl.cx(q[2], q[3])
hhl.cp(-3 * π / 4, q[2], q[3])
hhl.cx(q[2], q[3])
hhl.cp(-3 * π / 4, q[2], q[3])
hhl.cu(-π / 2, π / 2, -π / 2, 0, q[2], q[3])
# End of Inverse(Controlled-U0)
hhl.h(q[2])
hhl.h(q[1]);

print(hhl.draw())
# Out:
#                                                                             »
# q0_0: ──────────────────────────────────────────────────────────────────────»
#       ┌───┐                                                                 »
# q0_1: ┤ H ├──────────────────────────────────────────────────────■───X──────»
#       ├───┤                                                      │   │ ┌───┐»
# q0_2: ┤ H ├──────────■────────────■──────────■───■──────────■────┼───X─┤ H ├»
#       └───┘┌─────────┴──────────┐ │P(3π/4) ┌─┴─┐ │P(3π/4) ┌─┴─┐┌─┴─┐   └───┘»
# q0_3: ─────┤ U(-π/2,-π/2,π/2,0) ├─■────────┤ X ├─■────────┤ X ├┤ X ├────────»
#            └────────────────────┘          └───┘          └───┘└───┘        »
# q0_4: ──────────────────────────────────────────────────────────────────────»
#                                                                             »
# q0_5: ──────────────────────────────────────────────────────────────────────»
#                                                                             »
# c0: 2/══════════════════════════════════════════════════════════════════════»
#                                                                             »
# «                        ┌──────────────┐┌───────────────┐                 »
# «q0_0: ──────────────────┤ U(π/8,0,0,0) ├┤ U(π/16,0,0,0) ├─────────────────»
# «                ┌───┐   └──────┬───────┘└───────┬───────┘   ┌───┐         »
# «q0_1: ─■────────┤ H ├─X────────■────────────────┼─────────X─┤ H ├─■───────»
# «       │P(-π/2) └───┘ │                         │         │ └───┘ │P(π/2) »
# «q0_2: ─■──────────────X─────────────────────────■─────────X───────■───────»
# «                                                                          »
# «q0_3: ────────────────────────────────────────────────────────────────────»
# «                                                                          »
# «q0_4: ────────────────────────────────────────────────────────────────────»
# «                                                                          »
# «q0_5: ────────────────────────────────────────────────────────────────────»
# «                                                                          »
# «c0: 2/════════════════════════════════════════════════════════════════════»
# «                                                                          »
# «
# «q0_0: ────────────────────────────────────────────────────────────────────────
# «                   ┌───┐
# «q0_1: ──────X───■──┤ H ├──────────────────────────────────────────────────────
# «      ┌───┐ │   │  └───┘                                                 ┌───┐
# «q0_2: ┤ H ├─X───┼────■───■───────────■───■───────────────────■───────────┤ H ├
# «      └───┘   ┌─┴─┐┌─┴─┐ │P(-3π/4) ┌─┴─┐ │P(-3π/4) ┌─────────┴──────────┐└───┘
# «q0_3: ────────┤ X ├┤ X ├─■─────────┤ X ├─■─────────┤ U(-π/2,π/2,-π/2,0) ├─────
# «              └───┘└───┘           └───┘           └────────────────────┘
# «q0_4: ────────────────────────────────────────────────────────────────────────
# «
# «q0_5: ────────────────────────────────────────────────────────────────────────
# «
# «c0: 2/════════════════════════════════════════════════════════════════════════
# «

# %% [markdown]
# # Rejection sampling on the ancilla register and a swap test
#
# The state $\left|x\right\rangle=A^{-1}\left|b\right\rangle\propto\sum_j \beta_j\lambda_j^{-1}\left|u_j\right\rangle$ that contains information about the solution to $Ax=b$ is that obtained when measuring $1$ on the ancilla state. We perform the post-selection by projecting onto the desired $\left|1\right\rangle$. To check that the solution is the expected one, we prepare the correct output state manually to perform a swap test with the outcome.

# %%
# Target state preparation
hhl.rz(-π, q[4])
hhl.p(π, q[4])
hhl.h(q[4])
hhl.ry(-0.9311623288419387, q[4])
hhl.rz(π, q[4])
# Swap test
hhl.h(q[5])
hhl.cx(q[4], q[3])
hhl.ccx(q[5], q[3], q[4])
hhl.cx(q[4], q[3])
hhl.h(q[5])

hhl.barrier(q)
hhl.measure(q[0], c[0])
hhl.measure(q[5], c[1]);
print(hhl.draw())
# Out:
#                                                                                »
# q0_0: ─────────────────────────────────────────────────────────────────────────»
#         ┌───┐                                                                  »
# q0_1: ──┤ H ├──────────────────────────────────────────────────────────────────»
#         ├───┤                                                                  »
# q0_2: ──┤ H ├─────────────■────────────■───────────────■─────────■──────────■──»
#         └───┘   ┌─────────┴──────────┐ │P(3π/4)      ┌─┴─┐       │P(3π/4) ┌─┴─┐»
# q0_3: ──────────┤ U(-π/2,-π/2,π/2,0) ├─■─────────────┤ X ├───────■────────┤ X ├»
#       ┌────────┐└──────┬──────┬──────┘  ┌───┐   ┌────┴───┴─────┐┌───────┐ └───┘»
# q0_4: ┤ Rz(-π) ├───────┤ P(π) ├─────────┤ H ├───┤ Ry(-0.93116) ├┤ Rz(π) ├──────»
#       └─┬───┬──┘       └──────┘         └───┘   └──────────────┘└───────┘      »
# q0_5: ──┤ H ├──────────────────────────────────────────────────────────────────»
#         └───┘                                                                  »
# c0: 2/═════════════════════════════════════════════════════════════════════════»
#                                                                                »
# «                                     ┌──────────────┐┌───────────────┐        »
# «q0_0: ───────────────────────────────┤ U(π/8,0,0,0) ├┤ U(π/16,0,0,0) ├────────»
# «                             ┌───┐   └──────┬───────┘└───────┬───────┘   ┌───┐»
# «q0_1: ──■───X───────■────────┤ H ├─X────────■────────────────┼─────────X─┤ H ├»
# «        │   │ ┌───┐ │P(-π/2) └───┘ │                         │         │ └───┘»
# «q0_2: ──┼───X─┤ H ├─■──────────────X─────────────────────────■─────────X──────»
# «      ┌─┴─┐   └───┘                                                           »
# «q0_3: ┤ X ├───────────────────────────────────────────────────────────────────»
# «      └───┘                                                                   »
# «q0_4: ────────────────────────────────────────────────────────────────────────»
# «                                                                              »
# «q0_5: ────────────────────────────────────────────────────────────────────────»
# «                                                                              »
# «c0: 2/════════════════════════════════════════════════════════════════════════»
# «                                                                              »
# «                                                            »
# «q0_0: ──────────────────────────────────────────────────────»
# «                            ┌───┐                           »
# «q0_1: ─■─────────────X───■──┤ H ├───────────────────────────»
# «       │P(π/2) ┌───┐ │   │  └───┘                           »
# «q0_2: ─■───────┤ H ├─X───┼────■───■───────────■───■─────────»
# «               └───┘   ┌─┴─┐┌─┴─┐ │P(-3π/4) ┌─┴─┐ │P(-3π/4) »
# «q0_3: ─────────────────┤ X ├┤ X ├─■─────────┤ X ├─■─────────»
# «                       └───┘└───┘           └───┘           »
# «q0_4: ──────────────────────────────────────────────────────»
# «                                                            »
# «q0_5: ──────────────────────────────────────────────────────»
# «                                                            »
# «c0: 2/══════════════════════════════════════════════════════»
# «                                                            »
# «                                            ░ ┌─┐
# «q0_0: ──────────────────────────────────────░─┤M├───
# «                                            ░ └╥┘
# «q0_1: ──────────────────────────────────────░──╫────
# «                            ┌───┐           ░  ║
# «q0_2: ──────────■───────────┤ H ├───────────░──╫────
# «      ┌─────────┴──────────┐├───┤     ┌───┐ ░  ║
# «q0_3: ┤ U(-π/2,π/2,-π/2,0) ├┤ X ├──■──┤ X ├─░──╫────
# «      └────────────────────┘└─┬─┘┌─┴─┐└─┬─┘ ░  ║
# «q0_4: ────────────────────────■──┤ X ├──■───░──╫────
# «                                 └─┬─┘┌───┐ ░  ║ ┌─┐
# «q0_5: ─────────────────────────────■──┤ H ├─░──╫─┤M├
# «                                      └───┘ ░  ║ └╥┘
# «c0: 2/═════════════════════════════════════════╩══╩═
# «                                               0  1

# %% [markdown]
# *Note: it is a good exercise to check that the right result is given by the state $\left|x\right\rangle=0.949\left|0\right\rangle + 0.314\left|1\right\rangle$, which is the state we prepare above.*
#
# There are two measurements performed, one of the ancilla register (for doing the post-selection) and another one that gives the result of the swap test. To calculate success probabilities, let us define some helper functions.

# %%
def get_psuccess(counts):
    '''Compute the success probability of the HHL protocol from the statistics

    :return: (float) The success probability.
    '''
    try:
        succ_rotation_fail_swap = counts['11']
    except KeyError:
        succ_rotation_fail_swap = 0
    try:
        succ_rotation_succ_swap = counts['01']
    except KeyError:
        succ_rotation_succ_swap = 0
    succ_rotation = succ_rotation_succ_swap + succ_rotation_fail_swap
    try:
        prob_swap_test_success = succ_rotation_succ_swap / succ_rotation
        print(succ_rotation_succ_swap)
        print(succ_rotation)
    except ZeroDivisionError:
        prob_swap_test_success = 0
    return prob_swap_test_success

# %% [markdown]
# Finally we run the circuit on the simulator

# %%
backend = Aer.get_backend('qasm_simulator')
job = backend.run(hhl, shots=1024)
result = job.result()
counts = result.get_counts(hhl)
print(counts)
display(plot_histogram(counts))
print(get_psuccess(counts))
# Out:
# {'01': 25, '00': 952, '10': 47}
# 25
# 25
# 1.0

# %% [markdown]
# Now, we run the circuit on real hardware.

# %%
# !pip install qiskit-ibm-runtime
# Out:
# Requirement already satisfied: qiskit-ibm-runtime in /Users/Stef/anaconda3/envs/MLenv/lib/python3.11/site-packages (0.40.1)
# Requirement already satisfied: requests>=2.19 in /Users/Stef/anaconda3/envs/MLenv/lib/python3.11/site-packages (from qiskit-ibm-runtime) (2.32.4)
# Requirement already satisfied: requests-ntlm>=1.1.0 in /Users/Stef/anaconda3/envs/MLenv/lib/python3.11/site-packages (from qiskit-ibm-runtime) (1.3.0)
# Requirement already satisfied: numpy>=1.13 in /Users/Stef/anaconda3/envs/MLenv/lib/python3.11/site-packages (from qiskit-ibm-runtime) (1.26.4)
# Requirement already satisfied: urllib3>=1.21.1 in /Users/Stef/anaconda3/envs/MLenv/lib/python3.11/site-packages (from qiskit-ibm-runtime) (2.5.0)
# Requirement already satisfied: python-dateutil>=2.8.0 in /Users/Stef/anaconda3/envs/MLenv/lib/python3.11/site-packages (from qiskit-ibm-runtime) (2.9.0)
# Requirement already satisfied: ibm-platform-services>=0.22.6 in /Users/Stef/anaconda3/envs/MLenv/lib/python3.11/site-packages (from qiskit-ibm-runtime) (0.68.0)
# Requirement already satisfied: pydantic>=2.5.0 in /Users/Stef/anaconda3/envs/MLenv/lib/python3.11/site-packages (from qiskit-ibm-runtime) (2.11.7)
# Requirement already satisfied: qiskit>=1.4.1 in /Users/Stef/anaconda3/envs/MLenv/lib/python3.11/site-packages (from qiskit-ibm-runtime) (2.1.1)
# Requirement already satisfied: packaging in /Users/Stef/anaconda3/envs/MLenv/lib/python3.11/site-packages (from qiskit-ibm-runtime) (24.0)
# Requirement already satisfied: ibm_cloud_sdk_core<4.0.0,>=3.24.2 in /Users/Stef/anaconda3/envs/MLenv/lib/python3.11/site-packages (from ibm-platform-services>=0.22.6->qiskit-ibm-runtime) (3.24.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/Stef/anaconda3/envs/MLenv/lib/python3.11/site-packages (from pydantic>=2.5.0->qiskit-ibm-runtime) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /Users/Stef/anaconda3/envs/MLenv/lib/python3.11/site-packages (from pydantic>=2.5.0->qiskit-ibm-runtime) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /Users/Stef/anaconda3/envs/MLenv/lib/python3.11/site-packages (from pydantic>=2.5.0->qiskit-ibm-runtime) (4.14.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in /Users/Stef/anaconda3/envs/MLenv/lib/python3.11/site-packages (from pydantic>=2.5.0->qiskit-ibm-runtime) (0.4.1)
# Requirement already satisfied: six>=1.5 in /Users/Stef/anaconda3/envs/MLenv/lib/python3.11/site-packages (from python-dateutil>=2.8.0->qiskit-ibm-runtime) (1.16.0)
# Requirement already satisfied: rustworkx>=0.15.0 in /Users/Stef/anaconda3/envs/MLenv/lib/python3.11/site-packages (from qiskit>=1.4.1->qiskit-ibm-runtime) (0.16.0)
# Requirement already satisfied: scipy>=1.5 in /Users/Stef/anaconda3/envs/MLenv/lib/python3.11/site-packages (from qiskit>=1.4.1->qiskit-ibm-runtime) (1.12.0)
# Requirement already satisfied: dill>=0.3 in /Users/Stef/anaconda3/envs/MLenv/lib/python3.11/site-packages (from qiskit>=1.4.1->qiskit-ibm-runtime) (0.3.7)
# Requirement already satisfied: stevedore>=3.0.0 in /Users/Stef/anaconda3/envs/MLenv/lib/python3.11/site-packages (from qiskit>=1.4.1->qiskit-ibm-runtime) (5.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/Stef/anaconda3/envs/MLenv/lib/python3.11/site-packages (from requests>=2.19->qiskit-ibm-runtime) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/Stef/anaconda3/envs/MLenv/lib/python3.11/site-packages (from requests>=2.19->qiskit-ibm-runtime) (3.6)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/Stef/anaconda3/envs/MLenv/lib/python3.11/site-packages (from requests>=2.19->qiskit-ibm-runtime) (2024.2.2)
# Requirement already satisfied: cryptography>=1.3 in /Users/Stef/anaconda3/envs/MLenv/lib/python3.11/site-packages (from requests-ntlm>=1.1.0->qiskit-ibm-runtime) (42.0.5)
# Requirement already satisfied: pyspnego>=0.4.0 in /Users/Stef/anaconda3/envs/MLenv/lib/python3.11/site-packages (from requests-ntlm>=1.1.0->qiskit-ibm-runtime) (0.11.2)
# Requirement already satisfied: cffi>=1.12 in /Users/Stef/anaconda3/envs/MLenv/lib/python3.11/site-packages (from cryptography>=1.3->requests-ntlm>=1.1.0->qiskit-ibm-runtime) (1.16.0)
# Requirement already satisfied: PyJWT<3.0.0,>=2.10.1 in /Users/Stef/anaconda3/envs/MLenv/lib/python3.11/site-packages (from ibm_cloud_sdk_core<4.0.0,>=3.24.2->ibm-platform-services>=0.22.6->qiskit-ibm-runtime) (2.10.1)
# Requirement already satisfied: pbr>=2.0.0 in /Users/Stef/anaconda3/envs/MLenv/lib/python3.11/site-packages (from stevedore>=3.0.0->qiskit>=1.4.1->qiskit-ibm-runtime) (6.1.1)
# Requirement already satisfied: pycparser in /Users/Stef/anaconda3/envs/MLenv/lib/python3.11/site-packages (from cffi>=1.12->cryptography>=1.3->requests-ntlm>=1.1.0->qiskit-ibm-runtime) (2.21)
# Requirement already satisfied: setuptools in /Users/Stef/anaconda3/envs/MLenv/lib/python3.11/site-packages (from pbr>=2.0.0->stevedore>=3.0.0->qiskit>=1.4.1->qiskit-ibm-runtime) (69.2.0)

# %%
from qiskit_ibm_runtime import QiskitRuntimeService, SamplerV2 as Sampler
from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager

ibm_quantum_service = QiskitRuntimeService(channel="ibm_quantum", token="your token")

backend = ibm_quantum_service.least_busy(operational=True, simulator=False)
print("Least busy backend:", backend.name)
# Out:
# /var/folders/0y/p40nt1td47xgs3zh4yrj4qwc0000gn/T/ipykernel_26138/4148467296.py:4: DeprecationWarning: The "ibm_quantum" channel option is deprecated and will be sunset on 1 July. After this date, "ibm_cloud", "ibm_quantum_platform", and "local" will be the only valid channels. Open Plan users should migrate now.  All other users should review the migration guide (https://quantum.cloud.ibm.com/docs/migration-guides/classic-iqp-to-cloud-iqp)to learn when to migrate.
#   ibm_quantum_service = QiskitRuntimeService(channel="ibm_quantum", token="your token")
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File ~/anaconda3/envs/MLenv/lib/python3.11/site-packages/qiskit_ibm_runtime/api/session.py:328, in RetrySession.request(self, method, url, bare, **kwargs)
#     327     response = super().request(method, final_url, headers=headers, **kwargs)
# --> 328     response.raise_for_status()
#     329 except RequestException as ex:
#     330     # Wrap the requests exceptions into a IBM Q custom one, for
#     331     # compatibility.
#
# File ~/anaconda3/envs/MLenv/lib/python3.11/site-packages/requests/models.py:1026, in Response.raise_for_status(self)
#    1025 if http_error_msg:
# -> 1026     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 401 Client Error: Unauthorized for url: https://auth.quantum.ibm.com/api/users/loginWithToken
#
# The above exception was the direct cause of the following exception:
#
# IBMNotAuthorizedError                     Traceback (most recent call last)
# Cell In[14], line 4
#       1 from qiskit_ibm_runtime import QiskitRuntimeService, SamplerV2 as Sampler
#       2 from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager
# ----> 4 ibm_quantum_service = QiskitRuntimeService(channel="ibm_quantum", token="your token")
#       6 backend = ibm_quantum_service.least_busy(operational=True, simulator=False)
#       7 print("Least busy backend:", backend.name)
#
# File ~/anaconda3/envs/MLenv/lib/python3.11/site-packages/qiskit_ibm_runtime/qiskit_runtime_service.py:215, in QiskitRuntimeService.__init__(self, channel, token, url, filename, name, instance, proxies, verify, private_endpoint, url_resolver, region, plans_preference)
#     204 else:
#     205     warnings.warn(
#     206         'The "ibm_quantum" channel option is deprecated and will be sunset on 1 July. '
#     207         'After this date, "ibm_cloud", "ibm_quantum_platform", and "local" will be the '
#    (...)
#     213         stacklevel=2,
#     214     )
# --> 215     auth_client = self._authenticate_ibm_quantum_account(self._client_params)
#     216     # Update client parameters to use authenticated values.
#     217     self._client_params.url = auth_client.current_service_urls()["services"]["runtime"]
#
# File ~/anaconda3/envs/MLenv/lib/python3.11/site-packages/qiskit_ibm_runtime/qiskit_runtime_service.py:412, in QiskitRuntimeService._authenticate_ibm_quantum_account(self, client_params)
#     405 if not version_info["new_api"] or "api-auth" not in version_info:
#     406     raise IBMInputValueError(
#     407         "The URL specified ({}) is not an IBM Quantum authentication URL. "
#     408         "Valid authentication URL: {}.".format(
#     409             client_params.url, QISKIT_IBM_RUNTIME_API_URL
#     410         )
#     411     )
# --> 412 auth_client = AuthClient(client_params)
#     413 service_urls = auth_client.current_service_urls()
#     414 if not service_urls.get("services", {}).get(SERVICE_NAME):
#
# File ~/anaconda3/envs/MLenv/lib/python3.11/site-packages/qiskit_ibm_runtime/api/clients/auth.py:39, in AuthClient.__init__(self, client_params)
#      36 self._service_urls = {}  # type: ignore[var-annotated]
#      38 self.auth_api = Api(RetrySession(self.auth_url, **client_params.connection_parameters()))
# ---> 39 self.base_api = self._init_service_clients(**client_params.connection_parameters())
#
# File ~/anaconda3/envs/MLenv/lib/python3.11/site-packages/qiskit_ibm_runtime/api/clients/auth.py:51, in AuthClient._init_service_clients(self, **request_kwargs)
#      42 """Initialize the clients used for communicating with the API.
#      43
#      44 Args:
#    (...)
#      48     Client for the API server.
#      49 """
#      50 # Request an access token.
# ---> 51 self.access_token = self._request_access_token()
#      52 self.auth_api.session.auth = QuantumAuth(access_token=self.access_token)
#      53 self._service_urls = self.user_urls()
#
# File ~/anaconda3/envs/MLenv/lib/python3.11/site-packages/qiskit_ibm_runtime/api/clients/auth.py:77, in AuthClient._request_access_token(self)
#      67 """Request a new access token from the API authentication service.
#      68
#      69 Returns:
#    (...)
#      74     RequestsApiError: If the request failed.
#      75 """
#      76 try:
# ---> 77     response = self.auth_api.login(self.api_token)
#      78     return response["id"]
#      79 except RequestsApiError as ex:
#      80     # Get the original exception that raised.
#
# File ~/anaconda3/envs/MLenv/lib/python3.11/site-packages/qiskit_ibm_runtime/api/rest/root.py:93, in Api.login(self, api_token)
#      84 """Login with token.
#      85
#      86 Args:
#    (...)
#      90     JSON response.
#      91 """
#      92 url = self.get_url("login")
# ---> 93 return self.session.post(
#      94     url, json={"apiToken": api_token}, headers=self._HEADER_JSON_CONTENT
#      95 ).json()
#
# File ~/anaconda3/envs/MLenv/lib/python3.11/site-packages/requests/sessions.py:637, in Session.post(self, url, data, json, **kwargs)
#     626 def post(self, url, data=None, json=None, **kwargs):
#     627     r"""Sends a POST request. Returns :class:`Response` object.
#     628
#     629     :param url: URL for the new :class:`Request` object.
#    (...)
#     634     :rtype: requests.Response
#     635     """
# --> 637     return self.request("POST", url, data=data, json=json, **kwargs)
#
# File ~/anaconda3/envs/MLenv/lib/python3.11/site-packages/qiskit_ibm_runtime/api/session.py:349, in RetrySession.request(self, method, url, bare, **kwargs)
#     347         message += f". {ex.response.text}"
#     348 if status_code == 401:
# --> 349     raise IBMNotAuthorizedError(message) from ex
#     350 if status_code == 503:  # Planned maintenance outage
#     351     raise RequestsApiError(
#     352         "Unexpected response received from server. Please check if the service "
#     353         "is in maintenance mode "
#     354         f"https://docs.quantum.ibm.com/announcements/service-alerts {message}"
#     355     )
#
# IBMNotAuthorizedError: '401 Client Error: Unauthorized for url: https://auth.quantum.ibm.com/api/users/loginWithToken. Login failed., Error code: 3446.'

# %%
#draw the circuit before transpiling
print("Circuit before transpiling")
print(hhl.draw())

# transpile the circuit
pm = generate_preset_pass_manager(optimization_level=1, backend=backend)
transpiled_hhl = pm.run(hhl)

#and print the circuit after transpiling
print("Circuit after transpiling")
print(transpiled_hhl.draw())

# %%
sampler = Sampler(backend=backend)
sampler.options.default_shots = 1024

job = sampler.run([transpiled_hhl])
print(f"Job ID: {job.job_id()}")
result = job.result()

counts = result[0].data.c0.get_counts()
display(plot_histogram(counts))
print(f"{result[0].data.c0.get_counts()}")

# %% [markdown]
# # References
# [1] Ganguly, S. (2021). Quantum Machine Learning: An Applied Approach. Apress.
#
# [2] J. Pan, Y. Cao, X. Yao, Z. Li, C. Ju, H. Chen, X. Peng, S. Kais, and J. Du. (2014). [Experimental realization of quantum algorithm for solving linear systems of equations](https://arxiv.org/abs/1302.1946). *Physical Review Letters* 89:022313. <a id='1'></a>
